# %%
# Dependencies

import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

from config import api_key

# %%
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
url='https://api.yelp.com/v3/businesses/search'
 
# paramaters
params = {'term':'music venue','location':'Denver','radius':20000,'limit':50}

# %%
req=requests.get(url, params=params, headers=headers)

parsed = json.loads(req.text)
 
# proceed only if the status code is 200
print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
# printing the text from the response 
print(json.dumps(parsed, indent=4))
# Out:
# {
#     "businesses": [
#         {
#             "id": "0IqSfcno328kCD374Q7R7g",
#             "alias": "your-moms-house-denver",
#             "name": "Your Mom's House",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/mMUnWRrb4k1qI7RL3iBgQg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/your-moms-house-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 47,
#             "categories": [
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "danceclubs",
#                     "title": "Dance Clubs"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 39.7367329,
#                 "longitude": -104.9795145
#             },
#             "transactions": [],
#             "price": "$",
#             "location": {
#                 "address1": "608 E 13th Ave",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Denver",
#                 "zip_code": "80203",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "608 E 13th Ave",
#                     "Denver, CO 80203"
#                 ]
#             },
#             "phone": "+13038604516",
#             "display_phone": "(303) 860-4516",
#             "distance": 803.9038389361751
#         },
#         {
#             "id": "_UXWmagvPB86UA3PE2revA",
#             "alias": "ogden-theatre-denver",
#             "name": "Ogden Theatre",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/i0dQa9VdDfKr9u1bAePcvg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/ogden-theatre-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 199,
#             "categories": [
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "venues",
#                     "title": "Venues & Event Spaces"
#                 },
#                 {
#                     "alias": "theater",
#                     "title": "Performing Arts"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.7402554155021,
#                 "longitude": -104.975281194851
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "935 E Colfax Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80218",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "935 E Colfax Ave",
#                     "Denver, CO 80218"
#                 ]
#             },
#             "phone": "+13038321874",
#             "display_phone": "(303) 832-1874",
#             "distance": 679.8366628641336
#         },
#         {
#             "id": "oAWkAw_C5ByIZQubcVgIBw",
#             "alias": "bluebird-theater-denver",
#             "name": "Bluebird Theater",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/rYk6l6d5aiBw6hfvWnOY3Q/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/bluebird-theater-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 173,
#             "categories": [
#                 {
#                     "alias": "theater",
#                     "title": "Performing Arts"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 39.740411290939,
#                 "longitude": -104.94837851818
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "3317 E Colfax Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80206",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "3317 E Colfax Ave",
#                     "Denver, CO 80206"
#                 ]
#             },
#             "phone": "+13033771666",
#             "display_phone": "(303) 377-1666",
#             "distance": 1947.1173489180035
#         },
#         {
#             "id": "8WGzLAv1Mu_R9amiMz6RuQ",
#             "alias": "the-soiled-dove-underground-denver",
#             "name": "The Soiled Dove Underground",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/iv2oHkL1tjWjiVGU1DUH_w/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-soiled-dove-underground-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 89,
#             "categories": [
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "venues",
#                     "title": "Venues & Event Spaces"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 39.71899,
#                 "longitude": -104.90128
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "7401 E 1st Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80230",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "7401 E 1st Ave",
#                     "Denver, CO 80230"
#                 ]
#             },
#             "phone": "+13033660007",
#             "display_phone": "(303) 366-0007",
#             "distance": 6189.800684005699
#         },
#         {
#             "id": "m6hFStjFi3KfRXf4v777Cw",
#             "alias": "mission-ballroom-denver-2",
#             "name": "Mission Ballroom",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/y2eZYPc2CfUsElOclV2_cA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/mission-ballroom-denver-2?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 43,
#             "categories": [
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 39.776207,
#                 "longitude": -104.969169
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "4242 Wynkoop St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Denver",
#                 "zip_code": "80216",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "4242 Wynkoop St",
#                     "Denver, CO 80216"
#                 ]
#             },
#             "phone": "",
#             "display_phone": "",
#             "distance": 4524.650241093033
#         },
#         {
#             "id": "TYf0Pii-XhKvwwnOhVo28g",
#             "alias": "fillmore-auditorium-denver",
#             "name": "Fillmore Auditorium",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-0g2pclNNsPi5KkOnbxPQg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/fillmore-auditorium-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 180,
#             "categories": [
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "theater",
#                     "title": "Performing Arts"
#                 }
#             ],
#             "rating": 3.0,
#             "coordinates": {
#                 "latitude": 39.740563,
#                 "longitude": -104.977189
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "1510 Clarkson St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80218",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "1510 Clarkson St",
#                     "Denver, CO 80218"
#                 ]
#             },
#             "phone": "+13038370360",
#             "display_phone": "(303) 837-0360",
#             "distance": 816.3508410939133
#         },
#         {
#             "id": "hrnBaK2NCvu9NGU4m8dGRw",
#             "alias": "larimer-lounge-denver",
#             "name": "Larimer Lounge",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/Gmiz1IWocEqr73gzOQuITA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/larimer-lounge-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 124,
#             "categories": [
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.7600399,
#                 "longitude": -104.98393
#             },
#             "transactions": [],
#             "price": "$",
#             "location": {
#                 "address1": "2721 Larimer St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80205",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "2721 Larimer St",
#                     "Denver, CO 80205"
#                 ]
#             },
#             "phone": "+13032911007",
#             "display_phone": "(303) 291-1007",
#             "distance": 2954.775202770799
#         },
#         {
#             "id": "c3QuHjgIkESyn_eD4EiACA",
#             "alias": "nocturne-denver",
#             "name": "Nocturne",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/Loh7Ya4GO_Uw7R7QYO4jog/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/nocturne-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 265,
#             "categories": [
#                 {
#                     "alias": "jazzandblues",
#                     "title": "Jazz & Blues"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 39.7595901,
#                 "longitude": -104.9845123
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$$",
#             "location": {
#                 "address1": "1330 27th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80205",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "1330 27th St",
#                     "Denver, CO 80205"
#                 ]
#             },
#             "phone": "+13032953333",
#             "display_phone": "(303) 295-3333",
#             "distance": 2947.3400411585912
#         },
#         {
#             "id": "4LiJ9Yz_OpKbCBbfLCj0yw",
#             "alias": "the-walnut-room-denver",
#             "name": "The Walnut Room",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/bxskC7GYz0BeM0vm-8cBow/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-walnut-room-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 253,
#             "categories": [
#                 {
#                     "alias": "pizza",
#                     "title": "Pizza"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.7644023,
#                 "longitude": -104.9797261
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "3131 Walnut St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80205",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "3131 Walnut St",
#                     "Denver, CO 80205"
#                 ]
#             },
#             "phone": "+13032951868",
#             "display_phone": "(303) 295-1868",
#             "distance": 3311.806647373658
#         },
#         {
#             "id": "DP1dL3wAp2yzKJ6Z2mr-UQ",
#             "alias": "herbs-hideout-denver",
#             "name": "Herb's Hideout",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/DN-773SnyguqOeM1P2CbOg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/herbs-hideout-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 95,
#             "categories": [
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "divebars",
#                     "title": "Dive Bars"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 39.75392,
#                 "longitude": -104.9918
#             },
#             "transactions": [],
#             "price": "$",
#             "location": {
#                 "address1": "2057 Larimer St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80205",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "2057 Larimer St",
#                     "Denver, CO 80205"
#                 ]
#             },
#             "phone": "+13032999555",
#             "display_phone": "(303) 299-9555",
#             "distance": 2751.12090780332
#         },
#         {
#             "id": "uQSpae3j0ml14hgkMZ375w",
#             "alias": "hi-dive-denver",
#             "name": "Hi-Dive",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/8y30qPSghB4QP2dpReNWpA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/hi-dive-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 117,
#             "categories": [
#                 {
#                     "alias": "divebars",
#                     "title": "Dive Bars"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.7163899,
#                 "longitude": -104.98786
#             },
#             "transactions": [],
#             "price": "$",
#             "location": {
#                 "address1": "7 S Broadway",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80223",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "7 S Broadway",
#                     "Denver, CO 80223"
#                 ]
#             },
#             "phone": "+13037330230",
#             "display_phone": "(303) 733-0230",
#             "distance": 2607.6226832424086
#         },
#         {
#             "id": "cLnrXcOzgwr0qiyJRlaGzg",
#             "alias": "cervantes-masterpiece-denver",
#             "name": "Cervantes' Masterpiece",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/Qg86cXIbPn4WGmvASR1FtQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/cervantes-masterpiece-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 97,
#             "categories": [
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.75453585,
#                 "longitude": -104.9788397
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "2637 Welton St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80205",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "2637 Welton St",
#                     "Denver, CO 80205"
#                 ]
#             },
#             "phone": "+13032971772",
#             "display_phone": "(303) 297-1772",
#             "distance": 2238.056671456324
#         },
#         {
#             "id": "fbRq3NgI-NTcWMnBYQK0FQ",
#             "alias": "gothic-theatre-englewood-2",
#             "name": "Gothic Theatre",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/lUOOXIBI5u4fUyCr57xK8A/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/gothic-theatre-englewood-2?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 138,
#             "categories": [
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.65764,
#                 "longitude": -104.98802
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "3263 S Broadway",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Englewood",
#                 "zip_code": "80113",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "3263 S Broadway",
#                     "Englewood, CO 80113"
#                 ]
#             },
#             "phone": "+13037899206",
#             "display_phone": "(303) 789-9206",
#             "distance": 8792.9767337838
#         },
#         {
#             "id": "9TNpeeRfAd3hCRBOAq6Jyg",
#             "alias": "dancin-shoes-denver",
#             "name": "Dancin' Shoes",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/F9s4rpwV9CO2ic5M_vdXfw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/dancin-shoes-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 9,
#             "categories": [
#                 {
#                     "alias": "djs",
#                     "title": "DJs"
#                 }
#             ],
#             "rating": 5.0,
#             "coordinates": {
#                 "latitude": 39.7375106811523,
#                 "longitude": -104.971900939941
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Denver",
#                 "zip_code": "80218",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "Denver, CO 80218"
#                 ]
#             },
#             "phone": "+13035017888",
#             "display_phone": "(303) 501-7888",
#             "distance": 315.8072509197713
#         },
#         {
#             "id": "QIylo75fUWlVXy73HKGNKg",
#             "alias": "mercury-cafe-denver",
#             "name": "Mercury Cafe",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/op8EVXeIYyH5uqzaTqTCEQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/mercury-cafe-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 289,
#             "categories": [
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.7507619,
#                 "longitude": -104.9851677
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "2199 California St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80205",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "2199 California St",
#                     "Denver, CO 80205"
#                 ]
#             },
#             "phone": "+13032949281",
#             "display_phone": "(303) 294-9281",
#             "distance": 2138.438588893061
#         },
#         {
#             "id": "smcqQSgZZafoKVC4ABVglg",
#             "alias": "dazzle-denver-2",
#             "name": "Dazzle",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/mLAtcAh2W0mU86jIOcHmFg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/dazzle-denver-2?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 487,
#             "categories": [
#                 {
#                     "alias": "jazzandblues",
#                     "title": "Jazz & Blues"
#                 },
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 39.7463777,
#                 "longitude": -104.9954119
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "1512 Curtis St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80202",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "1512 Curtis St",
#                     "Denver, CO 80202"
#                 ]
#             },
#             "phone": "+13038395100",
#             "display_phone": "(303) 839-5100",
#             "distance": 2467.131143891298
#         },
#         {
#             "id": "HWSOaP3WEWXdsBloIvIR_w",
#             "alias": "broadway-roxy-denver-2",
#             "name": "Broadway Roxy",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/GrLjmeLCXDrOkeDH1Hwdog/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/broadway-roxy-denver-2?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 44,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 39.7065743959939,
#                 "longitude": -104.987353868717
#             },
#             "transactions": [
#                 "restaurant_reservation"
#             ],
#             "location": {
#                 "address1": "554 S Broadway",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Denver",
#                 "zip_code": "80209",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "554 S Broadway",
#                     "Denver, CO 80209"
#                 ]
#             },
#             "phone": "+17204567041",
#             "display_phone": "(720) 456-7041",
#             "distance": 3536.0262662817822
#         },
#         {
#             "id": "m_27Of9wPCdMBXGNi70U0w",
#             "alias": "lions-lair-denver",
#             "name": "Lion's Lair",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/c_E85HjD6C2wHb9NA8LX6Q/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/lions-lair-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 68,
#             "categories": [
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "divebars",
#                     "title": "Dive Bars"
#                 },
#                 {
#                     "alias": "comedyclubs",
#                     "title": "Comedy Clubs"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 39.73983,
#                 "longitude": -104.96269
#             },
#             "transactions": [],
#             "price": "$",
#             "location": {
#                 "address1": "2022 E Colfax Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80206",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "2022 E Colfax Ave",
#                     "Denver, CO 80206"
#                 ]
#             },
#             "phone": "+13033209200",
#             "display_phone": "(303) 320-9200",
#             "distance": 792.4680273266833
#         },
#         {
#             "id": "JRwq6JtrpW1c445q2OBXWw",
#             "alias": "the-oriental-theater-denver",
#             "name": "The Oriental Theater",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/-f-IXM8TzpplzvbWW-d7Uw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-oriental-theater-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 94,
#             "categories": [
#                 {
#                     "alias": "movietheaters",
#                     "title": "Cinema"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 39.77671,
#                 "longitude": -105.04351
#             },
#             "transactions": [],
#             "price": "$",
#             "location": {
#                 "address1": "4335 W 44th Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80212",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "4335 W 44th Ave",
#                     "Denver, CO 80212"
#                 ]
#             },
#             "phone": "+17204200030",
#             "display_phone": "(720) 420-0030",
#             "distance": 7775.588089324349
#         },
#         {
#             "id": "vJ569GGRvjNOQjH260puUg",
#             "alias": "the-black-box-denver",
#             "name": "The Black Box",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/EQM5uOPEfK5rlS4aqiTbsA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-black-box-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 23,
#             "categories": [
#                 {
#                     "alias": "danceclubs",
#                     "title": "Dance Clubs"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.73674825,
#                 "longitude": -104.98313574
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "314 E 13th Ave",
#                 "address2": null,
#                 "address3": null,
#                 "city": "Denver",
#                 "zip_code": "80203",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "314 E 13th Ave",
#                     "Denver, CO 80203"
#                 ]
#             },
#             "phone": "+13038316207",
#             "display_phone": "(303) 831-6207",
#             "distance": 1110.6074808636915
#         },
#         {
#             "id": "Dn_HjV1xpae1kAB7vioxHg",
#             "alias": "lost-lake-lounge-denver",
#             "name": "Lost Lake Lounge",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/tvr9MBa5UgT1YGR48fd2ZQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/lost-lake-lounge-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 80,
#             "categories": [
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.73989,
#                 "longitude": -104.94474
#             },
#             "transactions": [],
#             "price": "$",
#             "location": {
#                 "address1": "3602 E Colfax Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80206",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "3602 E Colfax Ave",
#                     "Denver, CO 80206"
#                 ]
#             },
#             "phone": "+13032961003",
#             "display_phone": "(303) 296-1003",
#             "distance": 2235.114249237826
#         },
#         {
#             "id": "PqLOiIWnXKvgvhGI5ZKcHw",
#             "alias": "skylark-lounge-denver",
#             "name": "Skylark Lounge",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Z0Uj6AMh1_2XeVQ4atpPbw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/skylark-lounge-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 140,
#             "categories": [
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.71371,
#                 "longitude": -104.98714
#             },
#             "transactions": [],
#             "price": "$",
#             "location": {
#                 "address1": "140 S Broadway",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80209",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "140 S Broadway",
#                     "Denver, CO 80209"
#                 ]
#             },
#             "phone": "+13037227844",
#             "display_phone": "(303) 722-7844",
#             "distance": 2830.6165241970566
#         },
#         {
#             "id": "t09cPwGnUeKYgf73BsVjPQ",
#             "alias": "el-chapultepec-denver",
#             "name": "El Chapultepec",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/GtE2dG0OTnLBWu2t5NjD-g/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/el-chapultepec-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 160,
#             "categories": [
#                 {
#                     "alias": "jazzandblues",
#                     "title": "Jazz & Blues"
#                 },
#                 {
#                     "alias": "divebars",
#                     "title": "Dive Bars"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 39.7534260527383,
#                 "longitude": -104.993477186508
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$",
#             "location": {
#                 "address1": "1962 Market St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80202",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "1962 Market St",
#                     "Denver, CO 80202"
#                 ]
#             },
#             "phone": "+13032959126",
#             "display_phone": "(303) 295-9126",
#             "distance": 2812.071895151004
#         },
#         {
#             "id": "psESMQAg6u2MNnY5DzGcDQ",
#             "alias": "appaloosa-grill-denver-6",
#             "name": "Appaloosa Grill",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/dbqGLGGsHr0-bcDXTRb7Fg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/appaloosa-grill-denver-6?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 849,
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 39.7444359,
#                 "longitude": -104.9909603
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "535 16th St",
#                 "address2": "Ste 110",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80202",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "535 16th St",
#                     "Ste 110",
#                     "Denver, CO 80202"
#                 ]
#             },
#             "phone": "+17209321700",
#             "display_phone": "(720) 932-1700",
#             "distance": 2028.7347412184108
#         },
#         {
#             "id": "CjJwgWKIXmMSviedeuh8Qg",
#             "alias": "be-on-key-psychedelic-ripple-denver",
#             "name": "Be On Key Psychedelic Ripple",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/FfCH6GpE2wXzv_lClvB1Kg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/be-on-key-psychedelic-ripple-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 24,
#             "categories": [
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.7435471,
#                 "longitude": -104.98196378
#             },
#             "transactions": [],
#             "price": "$",
#             "location": {
#                 "address1": "1700 Logan St",
#                 "address2": null,
#                 "address3": null,
#                 "city": "Denver",
#                 "zip_code": "80203",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "1700 Logan St",
#                     "Denver, CO 80203"
#                 ]
#             },
#             "phone": "+13038617070",
#             "display_phone": "(303) 861-7070",
#             "distance": 1341.5664231738642
#         },
#         {
#             "id": "kz881VpJace1ETVJS3gsIg",
#             "alias": "globe-hall-denver",
#             "name": "Globe Hall",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/iFVKNzGDdPjXuQxh_xM0Sg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/globe-hall-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 58,
#             "categories": [
#                 {
#                     "alias": "divebars",
#                     "title": "Dive Bars"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "bbq",
#                     "title": "Barbeque"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 39.77801,
#                 "longitude": -104.98254
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "4483 Logan St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80216",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "4483 Logan St",
#                     "Denver, CO 80216"
#                 ]
#             },
#             "phone": "+13032961003",
#             "display_phone": "(303) 296-1003",
#             "distance": 4845.7717199442695
#         },
#         {
#             "id": "qmB8fsetAnwbfMR_rF300Q",
#             "alias": "paramount-theatre-denver",
#             "name": "Paramount Theatre",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/DzSPY5SmjxI6Jt3GEePJLw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/paramount-theatre-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 133,
#             "categories": [
#                 {
#                     "alias": "theater",
#                     "title": "Performing Arts"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.744361,
#                 "longitude": -104.99027
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "1621 Glenarm Pl",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80202",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "1621 Glenarm Pl",
#                     "Denver, CO 80202"
#                 ]
#             },
#             "phone": "+13038254904",
#             "display_phone": "(303) 825-4904",
#             "distance": 1974.1010061239922
#         },
#         {
#             "id": "Md8oTgn7B0eOv7sRPJlviQ",
#             "alias": "bar-louie-denver-denver-2",
#             "name": "Bar Louie Denver",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/6q85u4pFNicrbfS1zT8vtg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/bar-louie-denver-denver-2?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 472,
#             "categories": [
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "gastropubs",
#                     "title": "Gastropubs"
#                 }
#             ],
#             "rating": 3.0,
#             "coordinates": {
#                 "latitude": 39.78073091357,
#                 "longitude": -104.89088167
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "8332 Northfield Blvd",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80238",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "8332 Northfield Blvd",
#                     "Denver, CO 80238"
#                 ]
#             },
#             "phone": "+17206776600",
#             "display_phone": "(720) 677-6600",
#             "distance": 8443.470442842347
#         },
#         {
#             "id": "iwSpNPvpxwmjwrWHTAveeQ",
#             "alias": "the-venue-denver-2",
#             "name": "The Venue",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/gjyc1o1LTfzwh8BakRdVWg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-venue-denver-2?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 12,
#             "categories": [
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 39.8308373,
#                 "longitude": -105.0044215
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "price": "$",
#             "location": {
#                 "address1": "1451 Cortez St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80221",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "1451 Cortez St",
#                     "Denver, CO 80221"
#                 ]
#             },
#             "phone": "+13034283339",
#             "display_phone": "(303) 428-3339",
#             "distance": 10998.874690657585
#         },
#         {
#             "id": "67ux5754998XXts1CI4mHg",
#             "alias": "the-grizzly-rose-denver-2",
#             "name": "The Grizzly Rose",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/T-OrLfpmLm_VLuC2mpmhuQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-grizzly-rose-denver-2?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 196,
#             "categories": [
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "countrydancehalls",
#                     "title": "Country Dance Halls"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.7953080154151,
#                 "longitude": -104.986927571828
#             },
#             "transactions": [],
#             "price": "$",
#             "location": {
#                 "address1": "5450 N Valley Hwy",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80216",
#                 "country": "US",
# ...
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/wiXtOXrM3gKUkaYcll3oNg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/black-shirt-brewing-denver-3?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 325,
#             "categories": [
#                 {
#                     "alias": "breweries",
#                     "title": "Breweries"
#                 },
#                 {
#                     "alias": "pizza",
#                     "title": "Pizza"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 39.7697672895761,
#                 "longitude": -104.972935177909
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$",
#             "location": {
#                 "address1": "3719 Walnut St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80205",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "3719 Walnut St",
#                     "Denver, CO 80205"
#                 ]
#             },
#             "phone": "+13039932799",
#             "display_phone": "(303) 993-2799",
#             "distance": 3814.589261976626
#         },
#         {
#             "id": "OshekCrMxlX1tkwOPxXGfw",
#             "alias": "the-roxy-theatre-denver",
#             "name": "The Roxy Theatre",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/OJbqzWi8e9dB9v4u6n99hQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-roxy-theatre-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 19,
#             "categories": [
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 }
#             ],
#             "rating": 2.5,
#             "coordinates": {
#                 "latitude": 39.7538108825684,
#                 "longitude": -104.979759216309
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "2549 Welton St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80205",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "2549 Welton St",
#                     "Denver, CO 80205"
#                 ]
#             },
#             "phone": "+17202429782",
#             "display_phone": "(720) 242-9782",
#             "distance": 2184.853993631055
#         },
#         {
#             "id": "kmnfhAPB68ppqBkK-Sf2vQ",
#             "alias": "rocketspace-studios-denver",
#             "name": "RocketSpace Studios",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/vZ5s6mMsIm7SX7X4BfNIgg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/rocketspace-studios-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 3,
#             "categories": [
#                 {
#                     "alias": "recording_studios",
#                     "title": "Recording & Rehearsal Studios"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 39.7599,
#                 "longitude": -104.98412
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "2711 Larimer St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Denver",
#                 "zip_code": "80205",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "2711 Larimer St",
#                     "Denver, CO 80205"
#                 ]
#             },
#             "phone": "+17205151671",
#             "display_phone": "(720) 515-1671",
#             "distance": 2948.7174981526373
#         },
#         {
#             "id": "6F4_oM9oRzBDc7KeTEtvcw",
#             "alias": "wild-corgi-pub-denver",
#             "name": "Wild Corgi Pub",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Eu5cVEmkFZ2wCeX9Rb0YyQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/wild-corgi-pub-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 47,
#             "categories": [
#                 {
#                     "alias": "pubs",
#                     "title": "Pubs"
#                 },
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 39.736985832484,
#                 "longitude": -104.97218012
#             },
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "location": {
#                 "address1": "1223 E 13th Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80218",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "1223 E 13th Ave",
#                     "Denver, CO 80218"
#                 ]
#             },
#             "phone": "+13038327636",
#             "display_phone": "(303) 832-7636",
#             "distance": 231.91362059854177
#         },
#         {
#             "id": "curOE41RquQVx0awxRPScg",
#             "alias": "rhinoceropolis-denver",
#             "name": "Rhinoceropolis",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/6XEja-xkjaL1KBAP29wUZw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/rhinoceropolis-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 12,
#             "categories": [
#                 {
#                     "alias": "venues",
#                     "title": "Venues & Event Spaces"
#                 },
#                 {
#                     "alias": "galleries",
#                     "title": "Art Galleries"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 39.77109,
#                 "longitude": -104.9780399
#             },
#             "transactions": [],
#             "price": "$",
#             "location": {
#                 "address1": "3553 Brighton Blvd",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80238",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "3553 Brighton Blvd",
#                     "Denver, CO 80238"
#                 ]
#             },
#             "phone": "",
#             "display_phone": "",
#             "distance": 4013.6248589740376
#         },
#         {
#             "id": "KV9dSt_n-OR2lGQjX58ytQ",
#             "alias": "denver-comedy-lounge-denver",
#             "name": "Denver Comedy Lounge",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/AuHcYTpGJorksefQ6XiyCw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/denver-comedy-lounge-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 4,
#             "categories": [
#                 {
#                     "alias": "comedyclubs",
#                     "title": "Comedy Clubs"
#                 }
#             ],
#             "rating": 5.0,
#             "coordinates": {
#                 "latitude": 39.767914,
#                 "longitude": -104.9736806
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "3559 Larimer St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80205",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "3559 Larimer St",
#                     "Denver, CO 80205"
#                 ]
#             },
#             "phone": "+17204496963",
#             "display_phone": "(720) 449-6963",
#             "distance": 3613.529510351354
#         },
#         {
#             "id": "WcluDiynwZeeOTcuUqX87Q",
#             "alias": "the-1up-arcade-bar-colfax-denver",
#             "name": "The 1UP Arcade Bar - Colfax",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/T8Lf1Ohn0lDRCiMpPRILuA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-1up-arcade-bar-colfax-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 228,
#             "categories": [
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "arcades",
#                     "title": "Arcades"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.7401558,
#                 "longitude": -104.9781352
#             },
#             "transactions": [],
#             "price": "$",
#             "location": {
#                 "address1": "717 E Colfax Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80203",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "717 E Colfax Ave",
#                     "Denver, CO 80203"
#                 ]
#             },
#             "phone": "+13037362230",
#             "display_phone": "(303) 736-2230",
#             "distance": 848.7406344233699
#         },
#         {
#             "id": "fqVkNpn43o-XWxHJfFpBbg",
#             "alias": "the-church-denver-2",
#             "name": "The Church",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/4VZ2GeiUfwAXvh6Hv7gjKA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-church-denver-2?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 120,
#             "categories": [
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "danceclubs",
#                     "title": "Dance Clubs"
#                 }
#             ],
#             "rating": 3.0,
#             "coordinates": {
#                 "latitude": 39.735043,
#                 "longitude": -104.9857619
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "1160 Lincoln St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80203",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "1160 Lincoln St",
#                     "Denver, CO 80203"
#                 ]
#             },
#             "phone": "+13038323528",
#             "display_phone": "(303) 832-3528",
#             "distance": 1327.8896068132233
#         },
#         {
#             "id": "DZxCUXc4kRRB8WjtWNF9kA",
#             "alias": "the-rusty-bucket-bar-and-grill-lakewood",
#             "name": "The Rusty Bucket Bar and Grill",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/gL6U2D95I0o7WfZOACQbfg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-rusty-bucket-bar-and-grill-lakewood?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 75,
#             "categories": [
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "musicvenues",
#                     "title": "Music Venues"
#                 },
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 39.654979,
#                 "longitude": -105.081894
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$",
#             "location": {
#                 "address1": "3355 S Wadsworth Blvd",
#                 "address2": "Ste G101",
#                 "address3": "",
#                 "city": "Lakewood",
#                 "zip_code": "80227",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "3355 S Wadsworth Blvd",
#                     "Ste G101",
#                     "Lakewood, CO 80227"
#                 ]
#             },
#             "phone": "+13039806200",
#             "display_phone": "(303) 980-6200",
#             "distance": 13094.464762549454
#         },
#         {
#             "id": "vQeS4_jVes9imO8bfU2KCg",
#             "alias": "adrift-tiki-bar-denver",
#             "name": "Adrift Tiki Bar",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/yFqef_idViYCW0Ay72XEpQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/adrift-tiki-bar-denver?adjust_creative=wF1bldRCEuJWCI9AQjieGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wF1bldRCEuJWCI9AQjieGA",
#             "review_count": 491,
#             "categories": [
#                 {
#                     "alias": "tikibars",
#                     "title": "Tiki Bars"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 },
#                 {
#                     "alias": "hawaiian",
#                     "title": "Hawaiian"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 39.7126,
#                 "longitude": -104.9872
#             },
#             "transactions": [
#                 "delivery"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "218 S Broadway",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Denver",
#                 "zip_code": "80209",
#                 "country": "US",
#                 "state": "CO",
#                 "display_address": [
#                     "218 S Broadway",
#                     "Denver, CO 80209"
#                 ]
#             },
#             "phone": "+13037788454",
#             "display_phone": "(303) 778-8454",
#             "distance": 2930.037285224832
#         }
#     ],
#     "total": 681,
#     "region": {
#         "center": {
#             "longitude": -104.97024536132812,
#             "latitude": 39.73552421220229
#         }
#     }
# }

# %%
businesses = parsed["businesses"]

# Set list

venues = []
venue_price= []
venue_rating = []
 
for business in businesses:
    
    print("Name:", business["name"])
    print("Rating:", business["rating"])
    print("Address:", " ".join(business["location"]["display_address"]))
    print("Phone:", business["phone"])
    print("\n")
    
    id = business["id"]
 
    url="https://api.yelp.com/v3/businesses/" + id + "/reviews"
 
    req = requests.get(url, headers=headers).json()
 
    #parsed = json.loads(req.text)
 
    #reviews = parsed["reviews"]
 
    print("--- Reviews ---")
# Out:
# Name: Your Mom's House
# Rating: 4.0
# Address: 608 E 13th Ave Denver, CO 80203
# Phone: +13038604516
#
#
# --- Reviews ---
# Name: Ogden Theatre
# Rating: 3.5
# Address: 935 E Colfax Ave Denver, CO 80218
# Phone: +13038321874
#
#
# --- Reviews ---
# Name: Bluebird Theater
# Rating: 4.0
# Address: 3317 E Colfax Ave Denver, CO 80206
# Phone: +13033771666
#
#
# --- Reviews ---
# Name: The Soiled Dove Underground
# Rating: 4.0
# Address: 7401 E 1st Ave Denver, CO 80230
# Phone: +13033660007
#
#
# --- Reviews ---
# Name: Mission Ballroom
# Rating: 4.0
# Address: 4242 Wynkoop St Denver, CO 80216
# Phone:
#
#
# --- Reviews ---
# Name: Fillmore Auditorium
# Rating: 3.0
# Address: 1510 Clarkson St Denver, CO 80218
# Phone: +13038370360
#
#
# --- Reviews ---
# Name: Larimer Lounge
# Rating: 3.5
# Address: 2721 Larimer St Denver, CO 80205
# Phone: +13032911007
#
#
# --- Reviews ---
# Name: Nocturne
# Rating: 4.5
# Address: 1330 27th St Denver, CO 80205
# Phone: +13032953333
#
#
# --- Reviews ---
# Name: The Walnut Room
# Rating: 3.5
# Address: 3131 Walnut St Denver, CO 80205
# Phone: +13032951868
#
#
# --- Reviews ---
# Name: Herb's Hideout
# Rating: 4.0
# Address: 2057 Larimer St Denver, CO 80205
# Phone: +13032999555
#
#
# --- Reviews ---
# Name: Hi-Dive
# Rating: 3.5
# Address: 7 S Broadway Denver, CO 80223
# Phone: +13037330230
#
#
# --- Reviews ---
# Name: Cervantes' Masterpiece
# Rating: 3.5
# Address: 2637 Welton St Denver, CO 80205
# Phone: +13032971772
#
#
# --- Reviews ---
# Name: Gothic Theatre
# Rating: 3.5
# Address: 3263 S Broadway Englewood, CO 80113
# Phone: +13037899206
#
#
# --- Reviews ---
# Name: Dancin' Shoes
# Rating: 5.0
# Address: Denver, CO 80218
# Phone: +13035017888
#
#
# --- Reviews ---
# Name: Mercury Cafe
# Rating: 3.5
# Address: 2199 California St Denver, CO 80205
# Phone: +13032949281
#
#
# --- Reviews ---
# Name: Dazzle
# Rating: 4.0
# Address: 1512 Curtis St Denver, CO 80202
# Phone: +13038395100
#
#
# --- Reviews ---
# Name: Broadway Roxy
# Rating: 4.5
# Address: 554 S Broadway Denver, CO 80209
# Phone: +17204567041
#
#
# --- Reviews ---
# Name: Lion's Lair
# Rating: 4.0
# Address: 2022 E Colfax Ave Denver, CO 80206
# Phone: +13033209200
#
#
# --- Reviews ---
# Name: The Oriental Theater
# Rating: 4.0
# Address: 4335 W 44th Ave Denver, CO 80212
# Phone: +17204200030
#
#
# --- Reviews ---
# Name: The Black Box
# Rating: 3.5
# Address: 314 E 13th Ave Denver, CO 80203
# Phone: +13038316207
#
#
# --- Reviews ---
# Name: Lost Lake Lounge
# Rating: 3.5
# Address: 3602 E Colfax Ave Denver, CO 80206
# Phone: +13032961003
#
#
# --- Reviews ---
# Name: Skylark Lounge
# Rating: 3.5
# Address: 140 S Broadway Denver, CO 80209
# Phone: +13037227844
#
#
# --- Reviews ---
# Name: El Chapultepec
# Rating: 4.0
# Address: 1962 Market St Denver, CO 80202
# Phone: +13032959126
#
#
# --- Reviews ---
# Name: Appaloosa Grill
# Rating: 4.0
# Address: 535 16th St Ste 110 Denver, CO 80202
# Phone: +17209321700
#
#
# --- Reviews ---
# Name: Be On Key Psychedelic Ripple
# Rating: 3.5
# Address: 1700 Logan St Denver, CO 80203
# Phone: +13038617070
#
#
# --- Reviews ---
# Name: Globe Hall
# Rating: 4.0
# Address: 4483 Logan St Denver, CO 80216
# Phone: +13032961003
#
#
# --- Reviews ---
# Name: Paramount Theatre
# Rating: 3.5
# Address: 1621 Glenarm Pl Denver, CO 80202
# Phone: +13038254904
#
#
# --- Reviews ---
# Name: Bar Louie Denver
# Rating: 3.0
# Address: 8332 Northfield Blvd Denver, CO 80238
# Phone: +17206776600
#
#
# --- Reviews ---
# Name: The Venue
# Rating: 4.0
# Address: 1451 Cortez St Denver, CO 80221
# Phone: +13034283339
#
#
# --- Reviews ---
# Name: The Grizzly Rose
# Rating: 3.5
# Address: 5450 N Valley Hwy Denver, CO 80216
# Phone: +13032951330
#
#
# --- Reviews ---
# Name: Local 46
# Rating: 4.0
# Address: 4586 Tennyson St Denver, CO 80212
# Phone: +17205243792
#
#
# --- Reviews ---
# Name: Herman's Hideaway
# Rating: 3.5
# Address: 1578 S Broadway Denver, CO 80210
# Phone: +13037775840
#
#
# --- Reviews ---
# Name: Zio Romolo's Alley Bar
# Rating: 4.0
# Address: 2400 W 32nd Ave Denver, CO 80211
# Phone: +13034774900
#
#
# --- Reviews ---
# Name: Ophelia's Electric Soapbox
# Rating: 4.5
# Address: 1215 20th St Denver, CO 80202
# Phone: +13039938023
#
#
# --- Reviews ---
# Name: Postino LoHi
# Rating: 4.5
# Address: 2715 17th St Denver, CO 80211
# Phone: +13034336363
#
#
# --- Reviews ---
# Name: The Thin Man
# Rating: 4.0
# Address: 2015 E 17th Ave Denver, CO 80206
# Phone: +13033207814
#
#
# --- Reviews ---
# Name: Quixote's True Blue Cafe
# Rating: 3.5
# Address: 1700 Logan St Denver, CO 80203
# Phone: +13038617070
#
#
# --- Reviews ---
# Name: The Bar Car
# Rating: 4.0
# Address: 819 Colorado Blvd Denver, CO 80206
# Phone: +17205248099
#
#
# --- Reviews ---
# Name: The Black Buzzard
# Rating: 5.0
# Address: 1624 Market St Denver, CO 80202
# Phone: +17205023535
#
#
# --- Reviews ---
# Name: BurlyCute Burlesque
# Rating: 4.5
# Address: 314 E 13th Ave Bender's Tavern Denver, CO 80203
# Phone: +13032951883
#
#
# --- Reviews ---
# Name: Black Shirt Brewing
# Rating: 4.5
# Address: 3719 Walnut St Denver, CO 80205
# Phone: +13039932799
#
#
# --- Reviews ---
# Name: The Roxy Theatre
# Rating: 2.5
# Address: 2549 Welton St Denver, CO 80205
# Phone: +17202429782
#
#
# --- Reviews ---
# Name: RocketSpace Studios
# Rating: 4.5
# Address: 2711 Larimer St Denver, CO 80205
# Phone: +17205151671
#
#
# --- Reviews ---
# Name: Wild Corgi Pub
# Rating: 4.5
# Address: 1223 E 13th Ave Denver, CO 80218
# Phone: +13038327636
#
#
# --- Reviews ---
# Name: Rhinoceropolis
# Rating: 4.0
# Address: 3553 Brighton Blvd Denver, CO 80238
# Phone:
#
#
# --- Reviews ---
# Name: Denver Comedy Lounge
# Rating: 5.0
# Address: 3559 Larimer St Denver, CO 80205
# Phone: +17204496963
#
#
# --- Reviews ---
# Name: The 1UP Arcade Bar - Colfax
# Rating: 3.5
# Address: 717 E Colfax Ave Denver, CO 80203
# Phone: +13037362230
#
#
# --- Reviews ---
# Name: The Church
# Rating: 3.0
# Address: 1160 Lincoln St Denver, CO 80203
# Phone: +13038323528
#
#
# --- Reviews ---
# Name: The Rusty Bucket Bar and Grill
# Rating: 3.5
# Address: 3355 S Wadsworth Blvd Ste G101 Lakewood, CO 80227
# Phone: +13039806200
#
#
# --- Reviews ---
# Name: Adrift Tiki Bar
# Rating: 4.0
# Address: 218 S Broadway Denver, CO 80209
# Phone: +13037788454
#
#
# --- Reviews ---
